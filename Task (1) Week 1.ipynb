# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("Task (1) Dataset.csv")
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver
# 0      17:02:00      Monday              18-30          Male  \
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience
# 0       Above high school                Employee              1-2yr  \
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df["Types_of_Junction"].sample(5)
# Out:
# 3140         Y Shape
# 10565            NaN
# 9565     No junction
# 4800     No junction
# 4064         Y Shape
# Name: Types_of_Junction, dtype: object

# %%
df.drop("Defect_of_vehicle", axis=1 , inplace = True)
df.drop("Service_year_of_vehicle", axis=1 , inplace = True)
df.drop("Fitness_of_casuality", axis=1 , inplace=True)
df.drop("Work_of_casuality", axis=1 , inplace=True)
df.drop("Type_of_vehicle", axis=1 , inplace=True)
df.drop("Age_band_of_casualty", axis = 1, inplace= True)
df.drop("Casualty_severity", axis = 1, inplace= True)
df.drop("Sex_of_casualty", axis = 1, inplace= True)
df.drop("Casualty_class", axis = 1, inplace= True)

#df = df.drop_duplicates()

df.dropna(subset="Area_accident_occured", inplace=True)
df.dropna(subset="Lanes_or_Medians", inplace=True)
df.dropna(subset="Road_allignment", inplace=True)
df.dropna(subset="Type_of_collision", inplace=True)
df.dropna(subset="Road_surface_type", inplace=True)
df.dropna(subset="Vehicle_movement", inplace=True)

# %%
df["Educational_level"].mode()
df["Educational_level"]= df["Educational_level"].fillna("Junior high school")
df["Vehicle_driver_relation"].mode()
df["Vehicle_driver_relation"] = df["Vehicle_driver_relation"].fillna("Employee")
df["Driving_experience"].mode()
df["Driving_experience"] = df["Driving_experience"].fillna("5-10yr")
df["Owner_of_vehicle"].mode()
df["Owner_of_vehicle"] = df["Owner_of_vehicle"].fillna("Owner")
df["Types_of_Junction"].mode()
df["Types_of_Junction"] = df["Types_of_Junction"].fillna("Y Shape")

# %%
df.isna().sum()
df.sample(5)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver
# 8009   12:25:00    Thursday           Under 18          Male  \
# 9171   18:00:00   Wednesday              31-50          Male
# 10599  15:55:00    Thursday              18-30          Male
# 11676  18:12:00   Wednesday              31-50          Male
# 3118    8:20:00    Thursday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience
# 8009   Junior high school                Employee         No Licence  \
# 9171    Elementary school                Employee              1-2yr
# 10599  Junior high school                Employee            unknown
# 11676  Junior high school                Employee             5-10yr
# 3118   Junior high school                   Owner             5-10yr
#
#       Owner_of_vehicle Area_accident_occured
# 8009             Owner     Residential areas  \
# 9171             Owner     Residential areas
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %% [markdown]
# in the below code:
#
# I did notice there is an "Unkown", "na" values. and they are marked as a value.
# so i did consider them as NULL and i cleaned them.

# %% [markdown]
# I did change the Day of the week to numricall.
#
# so saturday start at 0.

# %%
df["Age_band_of_driver"].mode()
#df["Age_band_of_driver"].value_counts("Unknown")
df["Age_band_of_driver"] = df["Age_band_of_driver"].str.replace("Unknown","18-30")
df["Sex_of_driver"] = df["Sex_of_driver"].str.replace("Unknown","Male")
df["Day_of_week"] = df["Day_of_week"].str.replace("Saturday","0")
df["Day_of_week"] = df["Day_of_week"].str.replace("Sunday","1")
df["Day_of_week"] = df["Day_of_week"].str.replace("Monday","2")
df["Day_of_week"] = df["Day_of_week"].str.replace("Tuesday","3")
df["Day_of_week"] = df["Day_of_week"].str.replace("Wednesday","4")
df["Day_of_week"] = df["Day_of_week"].str.replace("Thursday","5")
df["Day_of_week"] = df["Day_of_week"].str.replace("Friday","6")



#df['Casualty_severity'].mode()
#df["Casualty_severity"] = df["Casualty_severity"].str.replace("na","3")
#df["Casualty_class"].value_counts("na")
#df['Casualty_class'].mode()
#df["Sex_of_casualty"] = df["Sex_of_casualty"].str.replace("na","Male")
# Out:
# 1        2
# 3        1
# 4        1
# 7        6
# 8        6
#         ..
# 12311    4
# 12312    1
# 12313    1
# 12314    1
# 12315    1
# Name: Day_of_week, Length: 11030, dtype: object

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
#df.info()
df["Day_of_week"] = df["Day_of_week"].astype(int)

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 11030.000000          11030.000000
# mean                      2.041251              1.550045
# std                       0.689824              1.008167
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver
# 5536  14:33:00      Sunday              18-30          Male  \
# 734   18:30:00      Sunday            Over 51          Male
# 5410   7:53:00      Friday            Over 51          Male
# 5240  19:14:00      Monday              31-50          Male
# 6379  17:00:00      Monday              18-30          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience
# 5536   Elementary school                   Owner              2-5yr  \
# 734   Junior high school                Employee              2-5yr
# 5410  Junior high school                Employee              1-2yr
# 5240  Junior high school                Employee              2-5yr
# 6379  Junior high school                Employee             5-10yr
#
#      Owner_of_vehicle Area_accident_occured
# 5536            Owner          School areas  \
# 734             Owner    Recreational areas
# 5410            Owner                 Other
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
sns.histplot(df["Age_band_of_driver"])
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Count'>

# %%
g = sns.histplot(df["Area_accident_occured"])
g.figure.set_size_inches(30, 10)

# %%
sns.barplot(data = df, x= "Road_surface_conditions", y= "Number_of_vehicles_involved")
# Out:
# <Axes: xlabel='Road_surface_conditions', ylabel='Number_of_vehicles_involved'>

# %%
sns.barplot(data = df, x= "Day_of_week", y= "Number_of_casualties")
# Out:
# <Axes: xlabel='Day_of_week', ylabel='Number_of_casualties'>

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.histplot(df["Sex_of_driver"])
# Out:
# <Axes: xlabel='Sex_of_driver', ylabel='Count'>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df1= df[["Number_of_vehicles_involved","Number_of_casualties","Day_of_week"]].corr()
sns.heatmap(df1)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.histplot(df["Sex_of_driver"])
# Out:
# <Axes: xlabel='Sex_of_driver', ylabel='Count'>

# %%
sns.barplot(data = df, x= "Road_surface_conditions", y= "Number_of_vehicles_involved")
# Out:
# <Axes: xlabel='Road_surface_conditions', ylabel='Number_of_vehicles_involved'>

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sns.histplot(df["Age_band_of_driver"])
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Count'>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# based on my analysis, i can say :

# %% [markdown]
# 1- most of the accident was made by males.

# %% [markdown]
# 2- Drivers over 51 doesn't do a lot of accidents, so they are good if you considering giving them an insurance.

# %% [markdown]
# 3- Drivers between the age of 18 and 30 , should have a higher insurance cost.

# %% [markdown]
# 4- hostpitals should be alret when the weather is snowing especially if it was Sunday, cause the accidents raise in these conditions.

# %% [markdown]
# 5-the office area, one of the most dangerous areas when it come to car accdint, so we should put more signs there.
